# %%
import os
from plasma_fusion_simulation_tools.microinstability_analysis.src.basic_analysis_tools.growth_rate.growth_rate_plotting import gamma_omega_plot

from plasma_fusion_simulation_tools.microinstability_analysis.src.basic_analysis_tools.growth_rate.growth_rate_df_builder import growth_freq_dataframe
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import os
# ----> 2 from plasma_fusion_simulation_tools.microinstability_analysis.src.basic_analysis_tools.growth_rate.growth_rate_plotting import gamma_omega_plot
#       4 from plasma_fusion_simulation_tools.microinstability_analysis.src.basic_analysis_tools.growth_rate.growth_rate_df_builder import growth_freq_dataframe
#
# File ~/tools/plasma_fusion_simulation_tools/microinstability_analysis/src/basic_analysis_tools/growth_rate/growth_rate_plotting.py:6
#       3 import matplotlib.pyplot as plt
#       4 import math
# ----> 6 from plasma_fusion_simulation_tools.microinstability_analysis.src.basic_analysis_tools.growth_rate.growth_rate_df_builder import growth_freq_dataframe
#      12 def gamma_omega_plot(filepath, criteria_list = ['gamma', 'omega'], plot_mode='kymin', label_key='nz0', verbose = False):
#      14     if isinstance(filepath, str): filepath = [filepath]
#
# File ~/tools/plasma_fusion_simulation_tools/microinstability_analysis/src/basic_analysis_tools/growth_rate/growth_rate_df_builder.py:3
#       1 # import pandas as pd
# ----> 3 from GENE_sim_tools.GENE_sim_reader.src.dict_simulation_data import sim_filepath_to_df, criteria_smart_appender
#       4 from GENE_sim_tools.GENE_sim_reader.src.utils.file_functions import string_to_list
#       6 def growth_freq_dataframe(filepath, input_criteria = ['gamma', 'omega', 'status==CONVERGED']):
#
# ModuleNotFoundError: No module named 'GENE_sim_tools.GENE_sim_reader'

# %% [markdown]
# # 132588 q=5

# %% [markdown]
# ## Filepaths

# %%
base_path_132588_q_5 = '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode'

# %%
# Base kymin scans path
kymin_path = os.path.join(base_path_132588_q_5, 'kymin_scan')

# theta_0 (kx_center) scans
kx_center_path = os.path.join(base_path_132588_q_5, 'kx_center_scan')
# B_parallel false paths
bpar_F_path = os.path.join(base_path_132588_q_5, 'bpar_check')


# Convergence checks
nz0_0 = os.path.join(base_path_132588_q_5, 'convergence_check/kymin_scan_nz0_256')
nz0_1 = os.path.join(base_path_132588_q_5, 'convergence_check/kymin_scan_nz0_64')
nz0_2 = os.path.join(base_path_132588_q_5, 'convergence_check/kymin_scan_nz0_512')


nx0_0 = os.path.join(base_path_132588_q_5, 'convergence_check/kymin_scan_nx0_14')
nx0_paths = [nx0_0, kymin_path]

nv0_0 = os.path.join(base_path_132588_q_5, 'convergence_check/kymin_scan_nv0_72')
nv0_paths = [nv0_0, kymin_path]

nw0_0 = os.path.join(base_path_132588_q_5, 'convergence_check/kymin_scan_nw0_16')
nw0_paths = [nw0_0, kymin_path]

# %% [markdown]
# ## Base Growth Rates

# %%
verbose=False

print(kymin_path)
gamma_omega_plot(kymin_path, criteria_list=['kymin>0'], verbose=verbose)

print(kymin_path)
gamma_omega_plot(kymin_path, criteria_list=['kymin<=2'], verbose=verbose)
# Out:
# /pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan
# /pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan

# %% [markdown]
# ## Convergence Checks

# %% [markdown]
# ### nz0

# %%
print(kymin_path)
print(nz0_0)
nz0_paths_1 = [kymin_path, nz0_0, nz0_2]
# nz0_paths_1 = [nz0_0, nz0_2]

# gr_df = growth_freq_dataframe(nz0_paths_1)

# print(gr_df)

gamma_omega_plot(nz0_paths_1, label_key='nz0')
gamma_omega_plot(nz0_paths_1, label_key='nz0', criteria_list=['kymin<3'], verbose=True)
# Out:
# /pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan
# /pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/convergence_check/kymin_scan_nz0_256
# x-values for filepath: ['/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0005/omega_0001'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0001/omega_0001'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0004/omega_0001'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0004/omega_0002'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0001/omega_0002'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0005/omega_0002'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0004/omega_0003'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0001/omega_0003'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0000/omega_0001'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0003/omega_0001']
# x-values for filepath: ['/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/convergence_check/kymin_scan_nz0_256/scanfiles0002/omega_0001'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/convergence_check/kymin_scan_nz0_256/scanfiles0000/omega_0001'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/convergence_check/kymin_scan_nz0_256/scanfiles0002/omega_0002'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/convergence_check/kymin_scan_nz0_256/scanfiles0002/omega_0003'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/convergence_check/kymin_scan_nz0_256/scanfiles0001/omega_0001'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/convergence_check/kymin_scan_nz0_256/scanfiles0000/omega_0002'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/convergence_check/kymin_scan_nz0_256/scanfiles0001/omega_0002'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/convergence_check/kymin_scan_nz0_256/scanfiles0000/omega_0003']
# x-values for filepath: ['/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/convergence_check/kymin_scan_nz0_512/scanfiles0000/omega_0001'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/convergence_check/kymin_scan_nz0_512/scanfiles0000/omega_0002'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/convergence_check/kymin_scan_nz0_512/scanfiles0000/omega_0003'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/convergence_check/kymin_scan_nz0_512/scanfiles0000/omega_0004'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/convergence_check/kymin_scan_nz0_512/scanfiles0000/omega_0005'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/convergence_check/kymin_scan_nz0_512/scanfiles0000/omega_0006'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/convergence_check/kymin_scan_nz0_512/scanfiles0000/omega_0007'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/convergence_check/kymin_scan_nz0_512/scanfiles0000/omega_0008'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/convergence_check/kymin_scan_nz0_512/scanfiles0000/omega_0009']

# %%
# print(kymin_path)
# print(nz0_1)
# nz0_paths_2 = [nz0_1, kymin_path]
# gamma_omega_plot(nz0_paths_2, label_key='nz0')
# gamma_omega_plot(nz0_paths_2, label_key='nz0', criteria_list=['kymin>3'])
# gamma_omega_plot(nz0_paths_2, label_key='nz0', criteria_list=['kymin<=3'])

# %% [markdown]
# ### nx0

# %%
print(kymin_path)
print(nx0_0)

verbose = False
nx0_paths = [kymin_path, nx0_0]

# gamma_omega_plot(nx0_paths, label_key='nx0', verbose=True)
gamma_omega_plot(nx0_paths, label_key='nx0', verbose=verbose)
gamma_omega_plot(nx0_paths, label_key='nx0', verbose=verbose, criteria_list=['kymin<3'])
# Out:
# /pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan
# /pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/convergence_check/kymin_scan_nx0_14

# %% [markdown]
# ### nv0

# %%
print(kymin_path)
print(nv0_0)

verbose=True
nv0_paths = [kymin_path, nv0_0]
gamma_omega_plot(nv0_paths, label_key='nv0', verbose=verbose)
gamma_omega_plot(nv0_paths, label_key='nv0', verbose=verbose, criteria_list=['kymin<3'])
# Out:
# /pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan
# /pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/convergence_check/kymin_scan_nv0_72
# x-values for filepath: ['/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0005/omega_0001'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0001/omega_0001'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0004/omega_0001'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0004/omega_0002'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0001/omega_0002'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0005/omega_0002'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0004/omega_0003'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0001/omega_0003'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0000/omega_0001'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0003/omega_0001'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0003/omega_0002'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0003/omega_0003'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0000/omega_0002'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0002/omega_0001'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0000/omega_0003'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0007/omega_0001'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0007/omega_0002'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0002/omega_0002'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0007/omega_0003'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0006/omega_0002'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0002/omega_0003'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0006/omega_0003']
# x-values for filepath: ['/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/convergence_check/kymin_scan_nv0_72/scanfiles0000/omega_0001'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/convergence_check/kymin_scan_nv0_72/scanfiles0002/omega_0002'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/convergence_check/kymin_scan_nv0_72/scanfiles0001/omega_0001'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/convergence_check/kymin_scan_nv0_72/scanfiles0000/omega_0002'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/convergence_check/kymin_scan_nv0_72/scanfiles0002/omega_0003'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/convergence_check/kymin_scan_nv0_72/scanfiles0001/omega_0002'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/convergence_check/kymin_scan_nv0_72/scanfiles0000/omega_0003'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/convergence_check/kymin_scan_nv0_72/scanfiles0000/omega_0004'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/convergence_check/kymin_scan_nv0_72/scanfiles0000/omega_0005'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/convergence_check/kymin_scan_nv0_72/scanfiles0000/omega_0006'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/convergence_check/kymin_scan_nv0_72/scanfiles0000/omega_0007'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/convergence_check/kymin_scan_nv0_72/scanfiles0001/omega_0003'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/convergence_check/kymin_scan_nv0_72/scanfiles0000/omega_0008'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/convergence_check/kymin_scan_nv0_72/scanfiles0000/omega_0009']
# x-values for filepath: ['/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0005/omega_0001'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0001/omega_0001'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0004/omega_0001'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0004/omega_0002'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0001/omega_0002'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0005/omega_0002'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0004/omega_0003'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0001/omega_0003'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0000/omega_0001'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0003/omega_0001']
# x-values for filepath: ['/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/convergence_check/kymin_scan_nv0_72/scanfiles0000/omega_0001'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/convergence_check/kymin_scan_nv0_72/scanfiles0002/omega_0002'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/convergence_check/kymin_scan_nv0_72/scanfiles0001/omega_0001'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/convergence_check/kymin_scan_nv0_72/scanfiles0000/omega_0002'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/convergence_check/kymin_scan_nv0_72/scanfiles0002/omega_0003'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/convergence_check/kymin_scan_nv0_72/scanfiles0001/omega_0002'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/convergence_check/kymin_scan_nv0_72/scanfiles0000/omega_0003']

# %% [markdown]
# ### nw0

# %%
print(kymin_path)
print(nw0_0)


nw0_paths = [kymin_path, nw0_0]
verbose=True
gamma_omega_plot(nw0_paths, label_key='nw0', verbose=verbose)
gamma_omega_plot(nw0_paths, label_key='nw0', verbose=verbose, criteria_list=['kymin<3'])
# Out:
# /pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan
# /pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/convergence_check/kymin_scan_nw0_16
# x-values for filepath: ['/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0005/omega_0001'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0001/omega_0001'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0004/omega_0001'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0004/omega_0002'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0001/omega_0002'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0005/omega_0002'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0004/omega_0003'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0001/omega_0003'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0000/omega_0001'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0003/omega_0001'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0003/omega_0002'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0003/omega_0003'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0000/omega_0002'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0002/omega_0001'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0000/omega_0003'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0007/omega_0001'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0007/omega_0002'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0002/omega_0002'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0007/omega_0003'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0006/omega_0002'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0002/omega_0003'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0006/omega_0003']
# x-values for filepath: ['/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/convergence_check/kymin_scan_nw0_16/scanfiles0000/omega_0001'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/convergence_check/kymin_scan_nw0_16/scanfiles0001/omega_0001'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/convergence_check/kymin_scan_nw0_16/scanfiles0000/omega_0002'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/convergence_check/kymin_scan_nw0_16/scanfiles0001/omega_0002'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/convergence_check/kymin_scan_nw0_16/scanfiles0000/omega_0003'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/convergence_check/kymin_scan_nw0_16/scanfiles0000/omega_0004'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/convergence_check/kymin_scan_nw0_16/scanfiles0000/omega_0005'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/convergence_check/kymin_scan_nw0_16/scanfiles0000/omega_0006'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/convergence_check/kymin_scan_nw0_16/scanfiles0000/omega_0007'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/convergence_check/kymin_scan_nw0_16/scanfiles0001/omega_0003'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/convergence_check/kymin_scan_nw0_16/scanfiles0000/omega_0008'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/convergence_check/kymin_scan_nw0_16/scanfiles0000/omega_0009']
# x-values for filepath: ['/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0005/omega_0001'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0001/omega_0001'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0004/omega_0001'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0004/omega_0002'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0001/omega_0002'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0005/omega_0002'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0004/omega_0003'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0001/omega_0003'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0000/omega_0001'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/kymin_scan/scanfiles0003/omega_0001']
# x-values for filepath: ['/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/convergence_check/kymin_scan_nw0_16/scanfiles0000/omega_0001'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/convergence_check/kymin_scan_nw0_16/scanfiles0001/omega_0001'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/convergence_check/kymin_scan_nw0_16/scanfiles0000/omega_0002'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/convergence_check/kymin_scan_nw0_16/scanfiles0001/omega_0002'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.825_q=5_MTM_mode/convergence_check/kymin_scan_nw0_16/scanfiles0000/omega_0003']

# %% [markdown]
# ## Spatial Analysis

# %% [markdown]
# ### Theta_0 scans

# %%
# print(kx_center_path)
# print(kymin_path)

# path_list = [kymin_path, kx_center_path]

# # gamma_omega_plot(path_list, label_key='theta_0', plot_mode='theta_disk', verbose=True)
# gamma_omega_plot(path_list, label_key='theta_0', plot_mode='theta_disk')

# %% [markdown]
# ### B_parallel scans

# %%
# print(bpar_F_path)
# print(kymin_path)

# path_list = [kymin_path, bpar_F_path]

# gamma_omega_plot(path_list, label_key='bpar')
