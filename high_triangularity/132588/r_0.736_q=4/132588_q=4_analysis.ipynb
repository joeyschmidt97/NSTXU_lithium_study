# %%
import os
from plasma_fusion_simulation_tools.microinstability_analysis.src.basic_analysis_tools.growth_rate.growth_rate_plotting import gamma_omega_plot

from plasma_fusion_simulation_tools.microinstability_analysis.src.basic_analysis_tools.growth_rate.growth_rate_df_builder import growth_freq_dataframe

# %% [markdown]
# # 132588 q=4

# %% [markdown]
# ## Filepaths

# %%
base_path_132588_q_4 = '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.736_q=4_MTM_mode'

# %%
# Base kymin scans path
kymin_path = os.path.join(base_path_132588_q_4, 'kymin_scan')

# theta_0 (kx_center) scans
kx_center_path = os.path.join(base_path_132588_q_4, 'kx_center_scan')
# B_parallel false paths
bpar_F_path = os.path.join(base_path_132588_q_4, 'bpar_check')


# Convergence checks
nz0_0 = os.path.join(base_path_132588_q_4, 'convergence_check/kymin_scan_nz0_256')
nz0_1 = os.path.join(base_path_132588_q_4, 'convergence_check/kymin_scan_nz0_64')

nx0_0 = os.path.join(base_path_132588_q_4, 'convergence_check/kymin_scan_nx0_14')
nx0_1 = os.path.join(base_path_132588_q_4, 'convergence_check/kymin_scan_nx0_20')
nx0_paths = [nx0_0, kymin_path]

nv0_0 = os.path.join(base_path_132588_q_4, 'convergence_check/kymin_scan_nv0_72')
nv0_paths = [nv0_0, kymin_path]

nw0_0 = os.path.join(base_path_132588_q_4, 'convergence_check/kymin_scan_nw0_16')
nw0_paths = [nw0_0, kymin_path]

# %% [markdown]
# ## Base Growth Rates

# %%
base_kymin = growth_freq_dataframe(kymin_path)


# specific_kymin = base_kymin[base_kymin['kymin'] == 0.2]

# # Now extract the last 'n' characters of the filepath for this specific kymin
# specific_kymin['last_n_chars_filepath'] = specific_kymin['filepath'].str[-20:]

# print(specific_kymin[['kymin', 'omega', 'filepath', 'last_n_chars_filepath']])

# %%
verbose=False

print(kymin_path)
gamma_omega_plot(kymin_path, criteria_list=['kymin>0'], verbose=verbose)

print(kymin_path)
gamma_omega_plot(kymin_path, criteria_list=['kymin<=2'], verbose=verbose)

print(kymin_path)
gamma_omega_plot(kymin_path, criteria_list=['0.2<=kymin<=0.6'], verbose=verbose)
# Out:
# /pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.736_q=4_MTM_mode/kymin_scan
# /pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.736_q=4_MTM_mode/kymin_scan
# /pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.736_q=4_MTM_mode/kymin_scan

# %% [markdown]
# ## Convergence Checks

# %% [markdown]
# ### nz0

# %% [markdown]
# #### nz0=256

# %%
print(kymin_path)
print(nz0_0)

verbose=True
nz0_paths_1 = [kymin_path, nz0_0]
gamma_omega_plot(nz0_paths_1, label_key='nz0', criteria_list='hyp_z==-2')
gamma_omega_plot(nz0_paths_1, label_key='nz0', criteria_list=['kymin>3', 'hyp_z==-2'])
gamma_omega_plot(nz0_paths_1, label_key='nz0', criteria_list=['kymin<=3', 'hyp_z==-2'], verbose=verbose)
# Out:
# /pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.736_q=4_MTM_mode/kymin_scan
# /pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.736_q=4_MTM_mode/convergence_check/kymin_scan_nz0_256
# x-values for filepath: ['/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.736_q=4_MTM_mode/kymin_scan/scanfiles0011/omega_0001'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.736_q=4_MTM_mode/kymin_scan/scanfiles0008/omega_0001'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.736_q=4_MTM_mode/kymin_scan/scanfiles0011/omega_0002'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.736_q=4_MTM_mode/kymin_scan/scanfiles0008/omega_0002'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.736_q=4_MTM_mode/kymin_scan/scanfiles0011/omega_0003'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.736_q=4_MTM_mode/kymin_scan/scanfiles0009/omega_0003'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.736_q=4_MTM_mode/kymin_scan/scanfiles0008/omega_0003'
# ...

# %%
print(kymin_path)
print(nz0_0)

nz0_paths_1 = [kymin_path, nz0_0]

gamma_omega_plot(nz0_paths_1, label_key='hyp_z', criteria_list=['0<kymin<0.4', 'nz0==256'], verbose=True)
# Out:
# /pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.736_q=4_MTM_mode/kymin_scan
# /pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.736_q=4_MTM_mode/convergence_check/kymin_scan_nz0_256
# x-values for filepath: ['/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.736_q=4_MTM_mode/convergence_check/kymin_scan_nz0_256/scanfiles0005/omega_0006']
# x-values for filepath: ['/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.736_q=4_MTM_mode/convergence_check/kymin_scan_nz0_256/scanfiles0007/omega_0002'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.736_q=4_MTM_mode/convergence_check/kymin_scan_nz0_256/scanfiles0006/omega_0003'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.736_q=4_MTM_mode/convergence_check/kymin_scan_nz0_256/scanfiles0005/omega_0004'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.736_q=4_MTM_mode/convergence_check/kymin_scan_nz0_256/scanfiles0006/omega_0004'
# ...

# %% [markdown]
# #### nz0=64

# %%
print(kymin_path)
print(nz0_1)
nz0_paths_2 = [nz0_1, kymin_path]
gamma_omega_plot(nz0_paths_2, label_key='nz0')
gamma_omega_plot(nz0_paths_2, label_key='nz0', criteria_list=['kymin>3'])
gamma_omega_plot(nz0_paths_2, label_key='nz0', criteria_list=['kymin<=3'])
# Out:
# /pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.736_q=4_MTM_mode/kymin_scan
# /pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.736_q=4_MTM_mode/convergence_check/kymin_scan_nz0_64

# %% [markdown]
# ### nx0

# %%
print(kymin_path)
print(nx0_0)
print(nx0_1)

verbose = False
nx0_paths = [kymin_path, nx0_0, nx0_1]
# nx0_paths = [kymin_path, nx0_1]

# gamma_omega_plot(nx0_paths, label_key='nx0', verbose=True)
gamma_omega_plot(nx0_paths, label_key='nx0', verbose=verbose)
gamma_omega_plot(nx0_paths, label_key='nx0', verbose=verbose, criteria_list=['kymin<3'])
# Out:
# /pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.736_q=4_MTM_mode/kymin_scan
# /pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.736_q=4_MTM_mode/convergence_check/kymin_scan_nx0_14
# /pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.736_q=4_MTM_mode/convergence_check/kymin_scan_nx0_20

# %% [markdown]
# ### nv0

# %%
print(kymin_path)
print(nv0_0)

verbose=False
nv0_paths = [kymin_path, nv0_0]
gamma_omega_plot(nv0_paths, label_key='nv0', verbose=verbose, criteria_list=['gamma<0.25'])
gamma_omega_plot(nv0_paths, label_key='nv0', verbose=verbose, criteria_list=['kymin<3'])
# Out:
# /pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.736_q=4_MTM_mode/kymin_scan
# /pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.736_q=4_MTM_mode/convergence_check/kymin_scan_nv0_72

# %% [markdown]
# ### nw0

# %%
print(kymin_path)
print(nw0_0)

nw0_paths = [kymin_path, nw0_0]
verbose=False
gamma_omega_plot(nw0_paths, label_key='nw0', verbose=verbose)
gamma_omega_plot(nw0_paths, label_key='nw0', verbose=verbose, criteria_list=['kymin<3'])
# Out:
# /pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.736_q=4_MTM_mode/kymin_scan
# /pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.736_q=4_MTM_mode/convergence_check/kymin_scan_nw0_16

# %% [markdown]
# ### Theta_0 scans

# %%
# print(kx_center_path)
# print(kymin_path)

# path_list = [kymin_path, kx_center_path]

# # gamma_omega_plot(path_list, label_key='theta_0', plot_mode='theta_disk', verbose=True)
# gamma_omega_plot(path_list, label_key='theta_0', plot_mode='theta_disk')

# %% [markdown]
# ### B_parallel scans

# %%
# print(bpar_F_path)
# print(kymin_path)

# path_list = [kymin_path, bpar_F_path]

# gamma_omega_plot(path_list, label_key='bpar')
