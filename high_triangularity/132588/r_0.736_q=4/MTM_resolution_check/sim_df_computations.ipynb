# %%
import os

from GENE_sim_tools.GENE_sim_reader.src.full_sim_df.full_sim_df import converged_last_time_sim_df, sim_df_to_csv, load_csv_from_path

# %%
filepath = '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.736_q=4_MTM_mode/convergence_check/nz0_hpyz_edgeopt_scans'
res_sim_df = converged_last_time_sim_df(filepath)

# filepath = '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.736_q=4_MTM_mode/convergence_check/nz0_hpyz_edgeopt_scans/nz0_512_edgeopt_12'

# %%
len(sim_df['field_phi'][0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 len(sim_df['field_phi'][0])
#
# NameError: name 'sim_df' is not defined

# %%
sim_df_to_csv(filepath)
# Out:
# Saving simulation data to dataframe to path
#  /pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.736_q=4_MTM_mode/convergence_check/nz0_hpyz_edgeopt_scans

# %%
sim_df_loaded = load_csv_from_path('/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.736_q=4_MTM_mode/convergence_check/nz0_hpyz_edgeopt_scans')
