# %%
import sys
sys.path.append('/global/homes/j/joeschm/tools/ARCHIVE/GENE_code')

from GP_growth_rate import single_plot, gamma_omega_plot

# %% [markdown]
# # ~~~~~~~~~~~~~~~~~ 132588 ~~~~~~~~~~~~~~~~~~~~~

# %%
filepath = '/pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.736_q=4_MTM_mode/kymin_scan'
gamma_omega_plot(filepath, verbose=True)
# Out:
# x-values for filepath: /pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.736_q=4_MTM_mode/kymin_scan
# [0.5, 0.7, 1.0, 2.0, 3.0, 5.0, 7.0, 10.0, 50.0, 100.0]
#
#
# x-values for filepath: /pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.736_q=4_MTM_mode/kymin_scan
# [0.5, 0.7, 1.0, 2.0, 3.0, 5.0, 7.0, 10.0, 50.0, 100.0]

# %%
gamma_omega_plot(filepath, verbose=True)
# Out:
# x-values for filepath: /pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.736_q=4_MTM_mode/kymin_scan
# [0.5, 0.7, 1.0, 2.0, 3.0, 5.0, 7.0, 10.0, 50.0, 100.0]
#
#
# x-values for filepath: /pscratch/sd/j/joeschm/NSXTU_discharges/132588/r_0.736_q=4_MTM_mode/kymin_scan
# [0.5, 0.7, 1.0, 2.0, 3.0, 5.0, 7.0, 10.0, 50.0, 100.0]
