# %%
from GENE_sim_reader.src.dict_simulation_data import sim_filepath_to_df

from instability_analysis.src.basic_analysis_tools.growth_rate.growth_rate_df_builder import growth_freq_dataframe
from instability_analysis.src.basic_analysis_tools.growth_rate.growth_rate_plotting import gamma_omega_plot

import os

# %% [markdown]
# # 129015 OM

# %% [markdown]
# ### Filepaths

# %%
# NE_129015 = '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top'
# PE_129015 = '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.870001_PE_top'
base_path_129015 = '/pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.936008_OM_top'

# %%
# Base kymin scans path
kymin_path = os.path.join(base_path_129015, 'kymin_scan')

# theta_0 (kx_center) scans
kx_center_path = os.path.join(base_path_129015, 'kx_center_scan')
# B_parallel false paths
bpar_F_path = os.path.join(base_path_129015, 'bpar_check')


# Convergence checks
nz0_0 = os.path.join(base_path_129015, 'convergence_check/kymin_scan_nz0_256')
nz0_1 = os.path.join(base_path_129015, 'convergence_check/kymin_scan_nz0_64')

nx0_0 = os.path.join(base_path_129015, 'convergence_check/kymin_scan_nx0_10')
nx0_paths = [nx0_0, kymin_path]

nv0_0 = os.path.join(base_path_129015, 'convergence_check/kymin_scan_nv0_72')
nv0_paths = [nv0_0, kymin_path]

nw0_0 = os.path.join(base_path_129015, 'convergence_check/kymin_scan_nw0_16')
nw0_paths = [nw0_0, kymin_path]

# %% [markdown]
# ### Base Growth Rates

# %%
print(kymin_path)

gamma_omega_plot(kymin_path)
# Out:
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.936008_OM_top/kymin_scan

# %% [markdown]
# ### Convergence Checks

# %%
print(kymin_path)
print(nz0_0)
print(nz0_1)

nz0_paths = [kymin_path, nz0_0, nz0_1]

gamma_omega_plot(nz0_paths, label_key='nz0')
# Out:
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.936008_OM_top/kymin_scan
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.936008_OM_top/convergence_check/kymin_scan_nz0_256
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.936008_OM_top/convergence_check/kymin_scan_nz0_64

# %%
print(kymin_path)
print(nx0_0)

nx0_paths = [kymin_path, nx0_0]

gamma_omega_plot(nx0_paths, label_key='nx0')
# Out:
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.936008_OM_top/kymin_scan
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.936008_OM_top/convergence_check/kymin_scan_nx0_10
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 6
#       2 print(nx0_0)
#       4 nx0_paths = [kymin_path, nx0_0]
# ----> 6 gamma_omega_plot(nx0_paths, label_key='nx0')
#
# File ~/fusion_research/instability_analysis/src/basic_analysis_tools/growth_rate/growth_rate_plotting.py:15, in gamma_omega_plot(filepath, criteria_list, plot_mode, label_key, verbose)
#      11 def gamma_omega_plot(filepath, criteria_list = ['gamma', 'omega'], plot_mode='kymin', label_key='nz0', verbose = False):
#      13     if isinstance(filepath, str): filepath = [filepath]
# ---> 15     gr_sim_df = growth_freq_dataframe(filepath, criteria_list)
#      17     converged = gr_sim_df['status'] == 'CONVERGED'
# ...

# %%
print(kymin_path)
print(nv0_0)

nv0_paths = [kymin_path, nv0_0]

gamma_omega_plot(nv0_paths, label_key='nv0')
# Out:
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/kymin_scan
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.850026_NE_top/convergence_check/kymin_scan_nv0_72
# ---------------------------------------------------------------------------
# FileError                                 Traceback (most recent call last)
# Cell In[16], line 6
#       2 print(nv0_0)
#       4 nv0_paths = [kymin_path, nv0_0]
# ----> 6 gamma_omega_plot(nv0_paths, label_key='nv0')
#
# File ~/fusion_research/instability_analysis/src/basic_analysis_tools/growth_rate/growth_rate_plotting.py:15, in gamma_omega_plot(filepath, criteria_list, plot_mode, label_key, verbose)
#      11 def gamma_omega_plot(filepath, criteria_list = ['gamma', 'omega'], plot_mode='kymin', label_key='nz0', verbose = False):
#      13     if isinstance(filepath, str): filepath = [filepath]
# ---> 15     gr_sim_df = growth_freq_dataframe(filepath, criteria_list)
#      17     converged = gr_sim_df['status'] == 'CONVERGED'
# ...

# %% [markdown]
# ### Theta_0 scans

# %%
print(kx_center_path)
print(kymin_path)

path_list = [kymin_path, kx_center_path]

gamma_omega_plot(path_list, label_key='theta_0', plot_mode='theta_disk')
# Out:
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.936008_OM_top/kx_center_scan
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.936008_OM_top/kymin_scan
# [1.257 2.513 3.77  0.628 1.885 0.209 4.68  5.64  0.   ]

# %% [markdown]
# ### B_parallel scans

# %%
print(bpar_F_path)
print(kymin_path)

path_list = [kymin_path, bpar_F_path]

gamma_omega_plot(path_list, label_key='bpar')
# Out:
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.936008_OM_top/bpar_check
# /pscratch/sd/j/joeschm/NSXTU_discharges/129015/r_0.936008_OM_top/kymin_scan
