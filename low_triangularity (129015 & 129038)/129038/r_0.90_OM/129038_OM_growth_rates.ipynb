# %%
from GENE_sim_reader.src.dict_simulation_data import sim_filepath_to_df

from instability_analysis.src.basic_analysis_tools.growth_rate.growth_rate_df_builder import growth_freq_dataframe
from instability_analysis.src.basic_analysis_tools.growth_rate.growth_rate_plotting import gamma_omega_plot

import os

# %% [markdown]
# # 129038 OM

# %% [markdown]
# ### Filepaths

# %%
# PE_129038 = '/pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.499925_PE_top'
# NE_129038 = '/pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.655012_NE_top'
base_path_129038 = '/pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.909990_OM_top'

# %%
# Base kymin scans path
kymin_path = os.path.join(base_path_129038, 'kymin_scan')

# theta_0 (kx_center) scans
kx_center_path = os.path.join(base_path_129038, 'kx_center_scan')
# B_parallel false paths
bpar_F_path = os.path.join(base_path_129038, 'bpar_check')


# Convergence checks
nz0_0 = os.path.join(base_path_129038, 'convergence_check/kymin_scan_nz0_256')
nz0_1 = os.path.join(base_path_129038, 'convergence_check/kymin_scan_nz0_64')

nx0_0 = os.path.join(base_path_129038, 'convergence_check/kymin_scan_nx0_14')
nx0_paths = [nx0_0, kymin_path]

nv0_0 = os.path.join(base_path_129038, 'convergence_check/kymin_scan_nv0_72')
nv0_paths = [nv0_0, kymin_path]

nw0_0 = os.path.join(base_path_129038, 'convergence_check/kymin_scan_nw0_16')
nw0_paths = [nw0_0, kymin_path]

# %% [markdown]
# ### Base Growth Rates

# %%
print(kymin_path)

gamma_omega_plot(kymin_path)
# Out:
# /pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.909990_OM_top/kymin_scan

# %% [markdown]
# ### Convergence Checks

# %%
print(kymin_path)
print(nz0_0)
print(nz0_1)

nz0_paths = [kymin_path, nz0_0, nz0_1]

gamma_omega_plot(nz0_paths, label_key='nz0')
# Out:
# /pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.909990_OM_top/kymin_scan
# /pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.909990_OM_top/convergence_check/kymin_scan_nz0_256
# /pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.909990_OM_top/convergence_check/kymin_scan_nz0_64

# %%
print(kymin_path)
print(nx0_0)

nx0_paths = [kymin_path, nx0_0]

gamma_omega_plot(nx0_paths, label_key='nx0')
# Out:
# /pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.909990_OM_top/kymin_scan
# /pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.909990_OM_top/convergence_check/kymin_scan_nx0_14

# %%
print(kymin_path)
print(nv0_0)

nv0_paths = [kymin_path, nv0_0]

gamma_omega_plot(nv0_paths, label_key='nv0')
# Out:
# /pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.909990_OM_top/kymin_scan
# /pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.909990_OM_top/convergence_check/kymin_scan_nv0_72

# %% [markdown]
# ### Theta_0 scans

# %%
print(kx_center_path)
print(kymin_path)

path_list = [kymin_path, kx_center_path]

gamma_omega_plot(path_list, label_key='theta_0', plot_mode='theta_disk')
# Out:
# /pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.909990_OM_top/kx_center_scan
# /pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.909990_OM_top/kymin_scan
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/perlmutter/python-3.11/lib/python3.11/site-packages/pandas/core/indexes/base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'kx_center'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 6
#       2 print(kymin_path)
#       4 path_list = [kymin_path, kx_center_path]
# ----> 6 gamma_omega_plot(path_list, label_key='theta_0', plot_mode='theta_disk')
#
# File ~/fusion_research/instability_analysis/src/basic_analysis_tools/growth_rate/growth_rate_plotting.py:30, in gamma_omega_plot(filepath, criteria_list, plot_mode, label_key, verbose)
#      26         gr_sim_df['bpar'] = False
#      29 if (label_key.strip() == 'theta_0(deg)') or (label_key == 'theta_0'):
# ---> 30     gr_sim_df['kx_center'].fillna(0, inplace=True)
#      31     gr_sim_df['theta_0'] = gr_sim_df['kx_center']/(gr_sim_df['shat']*gr_sim_df['kymin'])
#      33     if label_key.strip() == 'theta_0(deg)':
#
# File ~/.local/perlmutter/python-3.11/lib/python3.11/site-packages/pandas/core/frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File ~/.local/perlmutter/python-3.11/lib/python3.11/site-packages/pandas/core/indexes/base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'kx_center'

# %% [markdown]
# ### B_parallel scans

# %%
print(bpar_F_path)
print(kymin_path)

path_list = [kymin_path, bpar_F_path]

gamma_omega_plot(path_list, label_key='bpar')
# Out:
# /pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.909990_OM_top/bpar_check
# /pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.909990_OM_top/kymin_scan
