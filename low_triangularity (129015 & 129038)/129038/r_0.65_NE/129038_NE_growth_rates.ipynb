# %%
from GENE_sim_reader.src.dict_simulation_data import sim_filepath_to_df

from instability_analysis.src.basic_analysis_tools.growth_rate.growth_rate_df_builder import growth_freq_dataframe
from instability_analysis.src.basic_analysis_tools.growth_rate.growth_rate_plotting import gamma_omega_plot

import os

# %% [markdown]
# # 129038 NE

# %% [markdown]
# ### Filepaths

# %%
# PE_129038 = '/pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.499925_PE_top'
base_path_129038 = '/pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.655012_NE_top'
# OM_129038 = '/pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.909990_OM_top'

# %%
# Base kymin scans path
kymin_path = os.path.join(base_path_129038, 'kymin_scan')

# theta_0 (kx_center) scans
kx_center_path = os.path.join(base_path_129038, 'kx_center_scan')
# B_parallel false paths
bpar_F_path = os.path.join(base_path_129038, 'bpar_check')


# Convergence checks
nz0_0 = os.path.join(base_path_129038, 'convergence_check/kymin_scan_nz0_256')
nz0_1 = os.path.join(base_path_129038, 'convergence_check/kymin_scan_nz0_64')

nx0_0 = os.path.join(base_path_129038, 'convergence_check/kymin_scan_nx0_14')
nx0_paths = [nx0_0, kymin_path]

nv0_0 = os.path.join(base_path_129038, 'convergence_check/kymin_scan_nv0_72')
nv0_paths = [nv0_0, kymin_path]

nw0_0 = os.path.join(base_path_129038, 'convergence_check/kymin_scan_nw0_16')
nw0_paths = [nw0_0, kymin_path]

# %% [markdown]
# ### Base Growth Rates

# %%
print(kymin_path)

gamma_omega_plot(kymin_path)
# Out:
# /pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.655012_NE_top/kymin_scan

# %% [markdown]
# ### Convergence Checks

# %%
print(kymin_path)
print(nz0_0)
print(nz0_1)

nz0_paths = [kymin_path, nz0_0, nz0_1]

gamma_omega_plot(nz0_paths, label_key='nz0')
# Out:
# /pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.655012_NE_top/kymin_scan
# /pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.655012_NE_top/convergence_check/kymin_scan_nz0_256
# /pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.655012_NE_top/convergence_check/kymin_scan_nz0_64

# %%
print(kymin_path)
print(nx0_0)

nx0_paths = [kymin_path, nx0_0]

gamma_omega_plot(nx0_paths, label_key='nx0')
# Out:
# /pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.655012_NE_top/kymin_scan
# /pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.655012_NE_top/convergence_check/kymin_scan_nx0_14

# %%
print(kymin_path)
print(nv0_0)

nv0_paths = [kymin_path, nv0_0]

gamma_omega_plot(nv0_paths, label_key='nv0')
# Out:
# /pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.655012_NE_top/kymin_scan
# /pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.655012_NE_top/convergence_check/kymin_scan_nv0_72

# %% [markdown]
# ### Theta_0 scans

# %%
print(kx_center_path)
print(kymin_path)

path_list = [kymin_path, kx_center_path]

gamma_omega_plot(path_list, label_key='theta_0', plot_mode='theta_disk')
# Out:
# /pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.655012_NE_top/kx_center_scan
# /pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.655012_NE_top/kymin_scan
# [1. 2. 3. 4. 0.]

# %% [markdown]
# ### B_parallel scans

# %%
print(bpar_F_path)
print(kymin_path)

path_list = [kymin_path, bpar_F_path]

# gamma_omega_plot(path_list, label_key='bpar', verbose=True, criteria_list=['kymin < 0.3'])
gamma_omega_plot(path_list, label_key='bpar', verbose=True)
# Out:
# /pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.655012_NE_top/bpar_check
# /pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.655012_NE_top/kymin_scan
# x-values for filepath: ['/pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.655012_NE_top/bpar_check/scanfiles0000/omega_0001'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.655012_NE_top/bpar_check/scanfiles0002/omega_0001'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.655012_NE_top/bpar_check/scanfiles0002/omega_0002'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.655012_NE_top/bpar_check/scanfiles0002/omega_0003'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.655012_NE_top/bpar_check/scanfiles0001/omega_0001'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.655012_NE_top/bpar_check/scanfiles0001/omega_0002'
#  '/pscratch/sd/j/joeschm/NSXTU_discharges/129038/r_0.655012_NE_top/bpar_check/scanfiles0001/omega_0003'
# ...
